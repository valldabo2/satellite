# %%
from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt

api = SentinelAPI(user='s5pguest', password='s5pguest', api_url='https://s5phub.copernicus.eu/dhus')

# %%
footprint = geojson_to_wkt(read_geojson('../glass-fire/map.geojson'))

products = api.query(
    footprint, 
    date=('20200920', "20201001"), 
    platformname='Sentinel-5',
    producttype='L2__CH4___'
)

product_df = api.to_dataframe(products)
product_df.head()
# Out:
#                                                                                   title  \
# fdcdf5fb-2d8b-488d-884e-294c81c6258d  S5P_OFFL_L2__CH4____20200930T191547_20200930T2...
# bc3eee08-82d6-4450-bd52-3ecf9306317e  S5P_OFFL_L2__CH4____20200930T205717_20200930T2...
# eb8dee8b-62f9-454d-bfc0-b646b2feb882  S5P_OFFL_L2__CH4____20200929T193456_20200929T2...
# c729f13c-6a55-4d27-bcd3-7e487c54472f  S5P_OFFL_L2__CH4____20200929T211625_20200929T2...
# b4c71c99-4bea-41e4-a2c6-20486a0f6f94  S5P_OFFL_L2__CH4____20200928T195404_20200928T2...
#
#                                                                                    link  \
# fdcdf5fb-2d8b-488d-884e-294c81c6258d  https://s5phub.copernicus.eu/odata/v1/Products...
# bc3eee08-82d6-4450-bd52-3ecf9306317e  https://s5phub.copernicus.eu/odata/v1/Products...
# eb8dee8b-62f9-454d-bfc0-b646b2feb882  https://s5phub.copernicus.eu/odata/v1/Products...
# c729f13c-6a55-4d27-bcd3-7e487c54472f  https://s5phub.copernicus.eu/odata/v1/Products...
# ...

# %%
# for product_id in products:
#     product_info = api.get_product_odata(product_id)
#     print(product_id, product_info["Online"])

# %%
api.download_all(products, directory_path='glass-fire/methane_data/')
